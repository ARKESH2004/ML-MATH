# %% [markdown]
# <a href="https://colab.research.google.com/github/ARKESH2004/ML-MATH/blob/main/MLvector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
v = np.array([1,-1,2])
w = np.array([2,5,2])

# %%
print(v+w)
# Out:
# [3 4 4]

# %%
print(v-w)
# Out:
# [-1 -6  0]

# %%
#sclr mult
print(3*v)
# Out:
# [ 3 -3  6]

# %%
print(np.linalg.norm(v))
# Out:
# 2.449489742783178

# %%
s = np.dot(v,w)
print(s)
# Out:
# 1
